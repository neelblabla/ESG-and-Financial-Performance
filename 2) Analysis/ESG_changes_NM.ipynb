# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import Common_Functions as cmn

# %%
#df = pd.read_csv(cmn.PATH_main_df_no_NAN_99p_YoY_Classified).drop(columns="Unnamed: 0")
df = pd.read_csv("../3) Data/main_df_no_NAN_99p_YoY_Classified.csv").drop(columns="Unnamed: 0")

# %%
# Correlation heatmap of 'ESG scores' and 'financial metrics'
financial_cols = ['Total Return', 'Revenue - Mean', 'Earnings Per Share - Mean', 
                  'Return On Equity - Mean', 'Volume', 'Company Market Cap', 'EBITDA - Mean']
esg_cols = ['ESG Score', 'ESG Combined Score', 'ESG Controversies Score', 
            'Social Pillar Score', 'Governance Pillar Score', 'Environmental Pillar Score']
cols = financial_cols + esg_cols
corr = df[cols].corr()

fig, ax = plt.subplots(figsize=(24, 8))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, cmap='coolwarm', annot_kws={"fontsize":8})
plt.title('Correlation Heatmap of ESG Scores and Financial Metrics', fontsize=14)
plt.show()

# %%
# Correlation heatmap of 'ESG scores' and 'financial metrics'
financial_cols = ['Total Return', 'Revenue - Mean YoY change', 'Earnings Per Share - Mean YoY change', 
                  'Return On Equity - Mean', 'Company Market Cap YoY change', 'EBITDA - Mean YoY change']
esg_cols = ['ESG Score YoY change', 'ESG Combined Score YoY change', 'ESG Controversies Score YoY change', 
            'Social Pillar Score YoY change', 'Governance Pillar Score YoY change']
cols = financial_cols + esg_cols
corr = df[cols].corr()

fig, ax = plt.subplots(figsize=(24, 8))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, cmap='coolwarm', annot_kws={"fontsize":8})
plt.title('Correlation Heatmap of ESG Scores and Financial Metrics', fontsize=14)
plt.show()

# %%
# filter dataframe for values below 25th percentile
q25_df = df[df['ESG Score YoY change'] < df['ESG Score YoY change'].quantile(0.25)]

# %%
# Correlation heatmap of 'ESG scores' and 'financial metrics'
financial_cols = ['Total Return', 'Revenue - Mean', 'Earnings Per Share - Mean', 
                  'Return On Equity - Mean', 'Volume', 'Company Market Cap', 'EBITDA - Mean']
esg_cols = ['ESG Score', 'ESG Combined Score', 'ESG Controversies Score', 
            'Social Pillar Score', 'Governance Pillar Score', 'Environmental Pillar Score']
cols = financial_cols + esg_cols
corr = q25_df[cols].corr()

fig, ax = plt.subplots(figsize=(24, 8))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, cmap='coolwarm', annot_kws={"fontsize":8})
plt.title('Correlation Heatmap of ESG Scores and Financial Metrics (ESG Return below 25% quartile)', fontsize=14)
plt.show()

# %%
# Correlation heatmap of 'ESG scores' and 'financial metrics'
financial_cols = ['Total Return', 'Revenue - Mean YoY change', 'Earnings Per Share - Mean YoY change', 
                  'Return On Equity - Mean', 'Volume YoY change', 'Company Market Cap YoY change', 'EBITDA - Mean YoY change']
esg_cols = ['ESG Score YoY change', 'ESG Combined Score YoY change', 'ESG Controversies Score YoY change', 
            'Social Pillar Score YoY change', 'Governance Pillar Score YoY change', 'Environmental Pillar Score YoY change']
cols = financial_cols + esg_cols
corr = q25_df[cols].corr()

fig, ax = plt.subplots(figsize=(24, 8))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, cmap='coolwarm', annot_kws={"fontsize":8})
plt.title('Correlation Heatmap of ESG Scores and Financial Metrics (ESG Return below 25% quartile)', fontsize=14)
plt.show()

# %%
# filter dataframe for values above 75th percentile
q75_df = df[df['ESG Score YoY change'] > df['ESG Score YoY change'].quantile(0.75)]

# %%
# Correlation heatmap of 'ESG scores' and 'financial metrics'
financial_cols = ['Total Return', 'Revenue - Mean', 'Earnings Per Share - Mean', 
                  'Return On Equity - Mean', 'Volume', 'Company Market Cap', 'EBITDA - Mean']
esg_cols = ['ESG Score', 'ESG Combined Score', 'ESG Controversies Score', 
            'Social Pillar Score', 'Governance Pillar Score', 'Environmental Pillar Score']
cols = financial_cols + esg_cols
corr = q75_df[cols].corr()

fig, ax = plt.subplots(figsize=(24, 8))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, cmap='coolwarm', annot_kws={"fontsize":8})
plt.title('Correlation Heatmap of ESG Scores and Financial Metrics (ESG Return above 75% quartile)', fontsize=14)
plt.show()

# %%
# Correlation heatmap of 'ESG scores' and 'financial metrics'
financial_cols = ['Total Return', 'Revenue - Mean YoY change', 'Earnings Per Share - Mean YoY change', 
                  'Return On Equity - Mean', 'Volume YoY change', 'Company Market Cap YoY change', 'EBITDA - Mean YoY change']
esg_cols = ['ESG Score YoY change', 'ESG Combined Score YoY change', 'ESG Controversies Score YoY change', 
            'Social Pillar Score YoY change', 'Governance Pillar Score YoY change', 'Environmental Pillar Score YoY change']
cols = financial_cols + esg_cols
corr = q75_df[cols].corr()

fig, ax = plt.subplots(figsize=(24, 8))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, cmap='coolwarm', annot_kws={"fontsize":8})
plt.title('Correlation Heatmap of ESG Scores and Financial Metrics (ESG Return above 75% quartile)', fontsize=14)
plt.show()

# %%
q75_df
# Out:
#                ISIN  Year  Total Return  ESG Score  ESG Combined Score  \
# 0      DK0010244508  2003     78.725725  16.933543           16.933543
# 4      DK0010244508  2007      3.167156  31.193987           31.193987
# 5      DK0010244508  2008    -47.670028  45.449992           45.449992
# 6      DK0010244508  2009     32.846102  62.791188           56.395594
# 12     DK0010244508  2015    -17.610147  61.102472           61.102472
# ...             ...   ...           ...        ...                 ...
# 41411  KYG9222R1065  2014     -8.690189  26.383482           26.383482
# 41412  KYG9222R1065  2015    -16.207962  33.154007           33.154007
# 41413  KYG9222R1065  2016     -7.760957  43.094243           43.094243
# 41417  KYG9222R1065  2020      0.611223  63.209642           63.209642
# 41426  FR0013326246  2007    -16.521731  73.652381           73.652381
#
#        ESG Controversies Score  Social Pillar Score  Governance Pillar Score  \
# 0                        100.0            19.033531                34.523810
# 4                        100.0            28.724879                23.602484
# 5                        100.0            36.182984                62.735507
# 6                         50.0            54.022668                63.714722
# 12                       100.0            68.357624                37.787274
# ...                        ...                  ...                      ...
# 41411                    100.0            25.168063                36.071429
# 41412                    100.0            28.795329                35.965278
# 41413                    100.0            35.290507                53.035088
# 41417                    100.0            52.372271                81.320302
# 41426                    100.0            70.885382                79.110106
#
#        Environmental Pillar Score  Revenue - Mean  ...  \
# 0                        0.000000    2.600826e+10  ...
# 4                       40.195106    5.364527e+10  ...
# 5                       41.084656    5.839820e+10  ...
# 6                       71.520807    5.096626e+10  ...
# 12                      72.672056    4.099216e+10  ...
# ...                           ...             ...  ...
# 41411                   20.172708    2.380830e+10  ...
# 41412                   37.490552    2.249530e+10  ...
# 41413                   46.768707    2.153403e+10  ...
# 41417                   64.724694    2.277265e+10  ...
# 41426                   71.201105    7.449527e+08  ...
#
#        Return On Equity - Mean Classified  ESG Score YoY change Classified  \
# 0                                       1                                1
# 4                                       1                                1
# 5                                       1                                1
# 6                                       0                                1
# 12                                      1                                1
# ...                                   ...                              ...
# 41411                                   1                                1
# 41412                                   1                                1
# 41413                                   1                                1
# 41417                                   1                                1
# 41426                                   1                                1
#
#        ESG Combined Score YoY change Classified  \
# 0                                             1
# 4                                             1
# 5                                             1
# 6                                             1
# 12                                            1
# ...                                         ...
# 41411                                         1
# 41412                                         1
# 41413                                         1
# 41417                                         1
# 41426                                         1
#
#        ESG Controversies Score YoY change Classified  \
# 0                                                  0
# 4                                                  1
# 5                                                  0
# 6                                                  0
# 12                                                 0
# ...                                              ...
# 41411                                              0
# 41412                                              0
# 41413                                              0
# 41417                                              0
# 41426                                              0
#
#        Social Pillar Score YoY change Classified  \
# 0                                              1
# 4                                              1
# 5                                              1
# 6                                              1
# 12                                             1
# ...                                          ...
# 41411                                          1
# 41412                                          1
# 41413                                          1
# 41417                                          1
# 41426                                          1
#
#       Governance Pillar Score YoY change Classified  \
# 0                                                 1
# 4                                                 0
# 5                                                 1
# 6                                                 1
# 12                                                1
# ...                                             ...
# 41411                                             1
# 41412                                             0
# 41413                                             1
# 41417                                             1
# 41426                                             1
#
#       Revenue - Mean YoY change Classified  \
# 0                                        1
# 4                                        1
# 5                                        1
# 6                                        0
# 12                                       0
# ...                                    ...
# 41411                                    0
# 41412                                    0
# 41413                                    0
# 41417                                    1
# 41426                                    1
#
#       Earnings Per Share - Mean YoY change Classified  \
# 0                                                   1
# 4                                                   1
# 5                                                   1
# 6                                                   0
# 12                                                  0
# ...                                               ...
# 41411                                               0
# 41412                                               1
# 41413                                               0
# 41417                                               1
# 41426                                               1
#
#       Company Market Cap YoY change Classified  \
# 0                                            1
# 4                                            1
# 5                                            0
# 6                                            1
# 12                                           0
# ...                                        ...
# 41411                                        1
# 41412                                        0
# 41413                                        0
# 41417                                        0
# 41426                                        1
#
#       EBITDA - Mean YoY change Classified
# 0                                       1
# 4                                       1
# 5                                       1
# 6                                       0
# 12                                      0
# ...                                   ...
# 41411                                   1
# 41412                                   1
# 41413                                   0
# 41417                                   1
# 41426                                   1
#
# [10358 rows x 41 columns]

# %%
q25_df
# Out:
#                ISIN  Year  Total Return  ESG Score  ESG Combined Score  \
# 2      DK0010244508  2005     45.463359  16.395483           16.395483
# 10     DK0010244508  2013     42.115239  57.083531           57.083531
# 11     DK0010244508  2014      7.396718  51.953292           51.953292
# 13     DK0010244508  2016     29.984775  56.550889           42.561159
# 43     US0003611052  2018     -4.312834  23.227339           23.227339
# ...             ...   ...           ...        ...                 ...
# 41404  CA90457D1006  2016    -12.963255  16.778274           16.778274
# 41406  CA90457D1006  2018    -30.417327  13.193986           13.193986
# 41409  KYG9222R1065  2012     77.406208  19.419869           19.419869
# 41416  KYG9222R1065  2019     24.356825  48.974416           48.974416
# 41425  FR0013326246  2006     69.575372  24.458032           24.458032
#
#        ESG Controversies Score  Social Pillar Score  Governance Pillar Score  \
# 2                   100.000000            20.152244                17.166667
# 10                   64.285714            51.417670                38.100000
# 11                  100.000000            50.885026                31.256410
# 13                   28.571429            61.827854                32.528736
# 43                  100.000000            33.704971                24.823140
# ...                        ...                  ...                      ...
# 41404               100.000000            20.078544                34.639066
# 41406               100.000000            20.359464                19.444444
# 41409               100.000000            23.824976                28.933333
# 41416               100.000000            37.047752                72.632769
# 41425               100.000000            31.540128                40.189255
#
#        Environmental Pillar Score  Revenue - Mean  ...  \
# 2                       11.683007    3.250909e+10  ...
# 10                      79.041156    5.988493e+10  ...
# 11                      70.357981    4.732617e+10  ...
# 13                      70.852638    3.582249e+10  ...
# 43                       1.683502    2.057629e+09  ...
# ...                           ...             ...  ...
# 41404                    0.000000    1.204736e+09  ...
# 41406                    0.000000    1.754679e+09  ...
# 41409                    4.741565    2.124414e+10  ...
# 41416                   47.535631    2.233141e+10  ...
# 41425                    5.274725    5.237316e+08  ...
#
#        Return On Equity - Mean Classified  ESG Score YoY change Classified  \
# 2                                       1                                0
# 10                                      1                                0
# 11                                      1                                0
# 13                                      1                                0
# 43                                      1                                0
# ...                                   ...                              ...
# 41404                                   1                                0
# 41406                                   1                                0
# 41409                                   1                                0
# 41416                                   1                                0
# 41425                                   1                                0
#
#        ESG Combined Score YoY change Classified  \
# 2                                             0
# 10                                            0
# 11                                            0
# 13                                            0
# 43                                            0
# ...                                         ...
# 41404                                         0
# 41406                                         0
# 41409                                         0
# 41416                                         0
# 41425                                         0
#
#        ESG Controversies Score YoY change Classified  \
# 2                                                  0
# 10                                                 0
# 11                                                 1
# 13                                                 0
# 43                                                 0
# ...                                              ...
# 41404                                              0
# 41406                                              0
# 41409                                              0
# 41416                                              0
# 41425                                              0
#
#        Social Pillar Score YoY change Classified  \
# 2                                              0
# 10                                             0
# 11                                             0
# 13                                             0
# 43                                             0
# ...                                          ...
# 41404                                          1
# 41406                                          0
# 41409                                          0
# 41416                                          1
# 41425                                          0
#
#       Governance Pillar Score YoY change Classified  \
# 2                                                 0
# 10                                                1
# 11                                                0
# 13                                                0
# 43                                                0
# ...                                             ...
# 41404                                             0
# 41406                                             0
# 41409                                             0
# 41416                                             0
# 41425                                             0
#
#       Revenue - Mean YoY change Classified  \
# 2                                        1
# 10                                       0
# 11                                       0
# 13                                       0
# 43                                       1
# ...                                    ...
# 41404                                    0
# 41406                                    1
# 41409                                    1
# 41416                                    0
# 41425                                    1
#
#       Earnings Per Share - Mean YoY change Classified  \
# 2                                                   1
# 10                                                  1
# 11                                                  1
# 13                                                  0
# 43                                                  1
# ...                                               ...
# 41404                                               1
# 41406                                               0
# 41409                                               1
# 41416                                               1
# 41425                                               1
#
#       Company Market Cap YoY change Classified  \
# 2                                            1
# 10                                           1
# 11                                           1
# 13                                           1
# 43                                           0
# ...                                        ...
# 41404                                        0
# 41406                                        0
# 41409                                        1
# 41416                                        1
# 41425                                        1
#
#       EBITDA - Mean YoY change Classified
# 2                                       0
# 10                                      0
# 11                                      0
# 13                                      0
# 43                                      1
# ...                                   ...
# 41404                                   1
# 41406                                   1
# 41409                                   1
# 41416                                   1
# 41425                                   1
#
# [10358 rows x 41 columns]

# %%
q25_df.columns.tolist()
# Out:
# ['ISIN',
#  'Year',
#  'Total Return',
#  'ESG Score',
#  'ESG Combined Score',
#  'ESG Controversies Score',
#  'Social Pillar Score',
#  'Governance Pillar Score',
#  'Environmental Pillar Score',
#  'Revenue - Mean',
#  'Earnings Per Share - Mean',
#  'Return On Equity - Mean',
#  'Volume',
#  'Company Market Cap',
#  'EBITDA - Mean',
#  'Country of Headquarters',
#  'Region of Headquarters',
#  'TRBC Industry Name',
#  'TRBC Industry Group Name',
#  'TRBC Business Sector Name',
#  'TRBC Economic Sector Name',
#  'ESG Score YoY change',
#  'ESG Combined Score YoY change',
#  'ESG Controversies Score YoY change',
#  'Social Pillar Score YoY change',
#  'Governance Pillar Score YoY change',
#  'Revenue - Mean YoY change',
#  'Earnings Per Share - Mean YoY change',
#  'Company Market Cap YoY change',
#  'EBITDA - Mean YoY change',
#  'Total Return Classified',
#  'Return On Equity - Mean Classified',
#  'ESG Score YoY change Classified',
#  'ESG Combined Score YoY change Classified',
#  'ESG Controversies Score YoY change Classified',
#  'Social Pillar Score YoY change Classified',
#  'Governance Pillar Score YoY change Classified',
#  'Revenue - Mean YoY change Classified',
#  'Earnings Per Share - Mean YoY change Classified',
#  'Company Market Cap YoY change Classified',
#  'EBITDA - Mean YoY change Classified']

# %%
# Correlation heatmap of 'ESG scores' and 'financial metrics'
financial_cols =  ['Total Return Classified','Revenue - Mean YoY change Classified',
 'Earnings Per Share - Mean YoY change Classified',
 'Company Market Cap YoY change Classified',
 'EBITDA - Mean YoY change Classified']
esg_cols = ['ESG Score YoY change', 'ESG Combined Score YoY change', 'ESG Controversies Score YoY change', 
            'Social Pillar Score YoY change', 'Governance Pillar Score YoY change', 'ESG Score',
 'ESG Combined Score',
 'ESG Controversies Score',
 'Social Pillar Score',
 'Governance Pillar Score',
 'Environmental Pillar Score']
cols = financial_cols + esg_cols
corr = q75_df[cols].corr()

fig, ax = plt.subplots(figsize=(24, 8))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, cmap='coolwarm', annot_kws={"fontsize":8})
plt.title('Correlation Heatmap of ESG Scores and Financial Metrics (ESG Return above 75% quartile)', fontsize=14)
plt.show()
